# %%
# !pip install
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Desktop/야구/22타자top30.csv', encoding='cp949', index_col = 1)
df.dropna(inplace=True)
df.drop('순', axis = 'columns', inplace=True)
df.drop('WAR*.1', axis = 'columns', inplace=True)
df.head()
# Out:
#          팀  WAR*    G   타석   타수   득점   안타  2타  3타  홈런  ...  병살 희타 희비     타율  \
# 이름                                                     ...
# 이정후  22키CF  9.23  142  627  553   85  193  36  10  23  ...  10  0  3  0.349
# 피렐라  22삼LF   7.4  141  630  561  102  192  33   4  28  ...  19  0  2  0.342
# 나성범  22KRF   6.5  144  649  563   92  180  39   2  21  ...   7  0  5   0.32
# 오지환  22LSS  5.77  142  569  494   75  133  16   4  25  ...  11  3  3  0.269
# 최정   22S3B  5.15  121  505  414   80  110  21   0  26  ...   6  0  6  0.266
#
#         출루     장타    OPS   wOBA   wRC+   WPA
# 이름
# 이정후  0.421  0.575  0.996  0.441  182.5  6.72
# 피렐라  0.411  0.565  0.976  0.434  169.3   4.2
# 나성범  0.402  0.508   0.91  0.411  157.4  3.74
# 오지환  0.357   0.47  0.827  0.372  138.6  2.56
# 최정   0.386  0.505  0.891    0.4  145.4  3.72
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 이정후 to 박찬호
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   팀       30 non-null     object
#  1   WAR*    30 non-null     object
#  2   G       30 non-null     object
#  3   타석      30 non-null     object
#  4   타수      30 non-null     object
#  5   득점      30 non-null     object
#  6   안타      30 non-null     object
#  7   2타      30 non-null     object
#  8   3타      30 non-null     object
#  9   홈런      30 non-null     object
#  10  루타      30 non-null     object
#  11  타점      30 non-null     object
#  12  도루      30 non-null     object
#  13  도실      30 non-null     object
#  14  볼넷      30 non-null     object
#  15  사구      30 non-null     object
#  16  고4      30 non-null     object
#  17  삼진      30 non-null     object
#  18  병살      30 non-null     object
#  19  희타      30 non-null     object
#  20  희비      30 non-null     object
# ...

# %%
df.iloc[:, 1:] = df.iloc[:, 1:].astype('float')

# %%
df.head(15)
# Out:
#            팀  WAR*      G     타석     타수     득점     안타    2타    3타    홈런  ...  \
# 이름                                                                       ...
# 이정후    22키CF  9.23  142.0  627.0  553.0   85.0  193.0  36.0  10.0  23.0  ...
# 피렐라    22삼LF   7.4  141.0  630.0  561.0  102.0  192.0  33.0   4.0  28.0  ...
# 나성범    22KRF   6.5  144.0  649.0  563.0   92.0  180.0  39.0   2.0  21.0  ...
# 오지환    22LSS  5.77  142.0  569.0  494.0   75.0  133.0  16.0   4.0  25.0  ...
# 최정     22S3B  5.15  121.0  505.0  414.0   80.0  110.0  21.0   0.0  26.0  ...
# 터크먼    22한CF  4.98  144.0  648.0  575.0   88.0  166.0  37.0   4.0  12.0  ...
# 소크라테스  22KCF  4.97  127.0  554.0  514.0   83.0  160.0  29.0   7.0  17.0  ...
# 김현수    22LLF  4.88  141.0  604.0  524.0   78.0  150.0  25.0   2.0  23.0  ...
# 김혜성    22키2B   4.8  129.0  566.0  516.0   81.0  164.0  18.0   7.0   4.0  ...
# 최지훈    22SCF  4.78  144.0  640.0  570.0   93.0  173.0  32.0   4.0  10.0  ...
# ...

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
font_list[:]
# Out:
# ['C:\\WINDOWS\\Fonts\\CENTAUR.TTF',
#  'C:\\Windows\\Fonts\\MN.TTF',
#  'C:\\WINDOWS\\Fonts\\CENTURY.TTF',
#  'C:\\WINDOWS\\Fonts\\gulim.ttc',
#  'C:\\Windows\\Fonts\\GLSNECB.TTF',
#  'C:\\Windows\\Fonts\\LFAXI.TTF',
#  'C:\\WINDOWS\\Fonts\\Candaral.ttf',
#  'C:\\Windows\\Fonts\\msjh.ttc',
#  'C:\\WINDOWS\\Fonts\\MJ.TTF',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'C:\\WINDOWS\\Fonts\\MN.TTF',
#  'C:\\WINDOWS\\Fonts\\JUICE___.TTF',
#  'C:\\Windows\\Fonts\\constan.ttf',
#  'C:\\WINDOWS\\Fonts\\ariblk.ttf',
#  'C:\\WINDOWS\\Fonts\\HMFMOLD.TTF',
#  'C:\\Windows\\Fonts\\LBRITEI.TTF',
#  'C:\\Windows\\Fonts\\CHILLER.TTF',
#  'C:\\WINDOWS\\Fonts\\CALISTB.TTF',
#  'C:\\WINDOWS\\Fonts\\KBIZ한마음고딕 B.ttf',
#  'C:\\WINDOWS\\Fonts\\BOD_PSTC.TTF',
#  'C:\\WINDOWS\\Fonts\\HANBatangExtBB.ttf',
#  'C:\\WINDOWS\\Fonts\\MH.TTF',
#  'C:\\Windows\\Fonts\\ARIALNB.TTF',
#  'C:\\WINDOWS\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\TCBI____.TTF',
#  'C:\\WINDOWS\\Fonts\\MK.TTF',
# ...

# %%
from matplotlib import font_manager, rc
font_path = 'C:\\WINDOWS\\Fonts\\KBIZ한마음고딕 B.ttf'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import numpy as np

# %%
HR_G = (df['홈런']/df['G'])
s_G = (df['도루']/df['G'])

HRs_G = pd.DataFrame([HR_G, s_G])
HRs_G
# Out:
# 이름       이정후       피렐라       나성범       오지환        최정       터크먼     소크라테스  \
# 0   0.161972  0.198582  0.145833  0.176056  0.214876  0.083333  0.133858
# 1   0.035211  0.106383  0.041667  0.140845  0.099174  0.131944  0.102362
#
# 이름       김현수       김혜성       최지훈  ...       이대호       박해민       장성우       노진혁  \
# 0   0.163121  0.031008  0.069444  ...  0.160839  0.020833  0.153846  0.130435
# 1   0.014184  0.263566  0.215278  ...  0.000000  0.166667  0.008547  0.017391
#
# 이름       허경민       안치홍       김재환       홍창기       전준우       박찬호
# 0   0.066116  0.106061  0.179688  0.008475  0.091667  0.030769
# 1   0.082645  0.053030  0.015625  0.110169  0.050000  0.315385
#
# [2 rows x 30 columns]

# %%
HRs_G = HRs_G.transpose()
HRs_G
# Out:
#            홈런/G      도루/G
# 이름
# 이정후    0.161972  0.035211
# 피렐라    0.198582  0.106383
# 나성범    0.145833  0.041667
# 오지환    0.176056  0.140845
# 최정     0.214876  0.099174
# 터크먼    0.083333  0.131944
# 소크라테스  0.133858  0.102362
# 김현수    0.163121  0.014184
# 김혜성    0.031008  0.263566
# 최지훈    0.069444  0.215278
# 양의지    0.153846  0.023077
# 박건우    0.090090  0.027027
# 박성한    0.014286  0.085714
# 문보경    0.071429  0.055556
# 마티니    0.115108  0.093525
# 한유섬    0.155556  0.007407
# 박병호    0.282258  0.040323
# 푸이그    0.166667  0.047619
# 한동희    0.108527  0.000000
# 정은원    0.057143  0.071429
# 이대호    0.160839  0.000000
# 박해민    0.020833  0.166667
# 장성우    0.153846  0.008547
# 노진혁    0.130435  0.017391
# 허경민    0.066116  0.082645
# 안치홍    0.106061  0.053030
# 김재환    0.179688  0.015625
# 홍창기    0.008475  0.110169
# 전준우    0.091667  0.050000
# 박찬호    0.030769  0.315385

# %%
HRs_G.rename(columns = {0 : '홈런/G',1 : '도루/G'}, inplace=True)
HRs_G
# Out:
#            홈런/G      도루/G
# 이름
# 이정후    0.161972  0.035211
# 피렐라    0.198582  0.106383
# 나성범    0.145833  0.041667
# 오지환    0.176056  0.140845
# 최정     0.214876  0.099174
# 터크먼    0.083333  0.131944
# 소크라테스  0.133858  0.102362
# 김현수    0.163121  0.014184
# 김혜성    0.031008  0.263566
# 최지훈    0.069444  0.215278
# 양의지    0.153846  0.023077
# 박건우    0.090090  0.027027
# 박성한    0.014286  0.085714
# 문보경    0.071429  0.055556
# 마티니    0.115108  0.093525
# 한유섬    0.155556  0.007407
# 박병호    0.282258  0.040323
# 푸이그    0.166667  0.047619
# 한동희    0.108527  0.000000
# 정은원    0.057143  0.071429
# 이대호    0.160839  0.000000
# 박해민    0.020833  0.166667
# 장성우    0.153846  0.008547
# 노진혁    0.130435  0.017391
# 허경민    0.066116  0.082645
# 안치홍    0.106061  0.053030
# 김재환    0.179688  0.015625
# 홍창기    0.008475  0.110169
# 전준우    0.091667  0.050000
# 박찬호    0.030769  0.315385

# %%
HRs_G.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='이름'>

# %%
HRs_G.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='이름'>

# %%
HRs_G.describe()
# Out:
#             홈런/G       도루/G
# count  30.000000  30.000000
# mean    0.118057   0.080725
# std     0.065542   0.077462
# min     0.008475   0.000000
# 25%     0.069940   0.024064
# 50%     0.122771   0.054293
# 75%     0.161689   0.105378
# max     0.282258   0.315385

# %%
HRs_G.loc[(HRs_G['홈런/G'] >= 0.12) & (HRs_G['도루/G'] >= 0.05), ['홈런/G', '도루/G']].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='이름'>

# %%
df
# Out:
#            팀  WAR*      G     타석     타수     득점     안타    2타    3타    홈런  ...  \
# 이름                                                                       ...
# 이정후    22키CF  9.23  142.0  627.0  553.0   85.0  193.0  36.0  10.0  23.0  ...
# 피렐라    22삼LF   7.4  141.0  630.0  561.0  102.0  192.0  33.0   4.0  28.0  ...
# 나성범    22KRF   6.5  144.0  649.0  563.0   92.0  180.0  39.0   2.0  21.0  ...
# 오지환    22LSS  5.77  142.0  569.0  494.0   75.0  133.0  16.0   4.0  25.0  ...
# 최정     22S3B  5.15  121.0  505.0  414.0   80.0  110.0  21.0   0.0  26.0  ...
# 터크먼    22한CF  4.98  144.0  648.0  575.0   88.0  166.0  37.0   4.0  12.0  ...
# 소크라테스  22KCF  4.97  127.0  554.0  514.0   83.0  160.0  29.0   7.0  17.0  ...
# 김현수    22LLF  4.88  141.0  604.0  524.0   78.0  150.0  25.0   2.0  23.0  ...
# 김혜성    22키2B   4.8  129.0  566.0  516.0   81.0  164.0  18.0   7.0   4.0  ...
# 최지훈    22SCF  4.78  144.0  640.0  570.0   93.0  173.0  32.0   4.0  10.0  ...
# ...
