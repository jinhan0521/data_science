# %% [markdown]
# # 작업 2유형

# %% [markdown]
# ### 서비스 이탈예측 데이터

# %%
import pandas as pd
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv")
x_test_data= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv")

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score, precision_score

#x_train 전처리
x_train_dummies = pd.get_dummies(x_train[['Geography', 'Gender']])
x_train = x_train[['CreditScore', 'Age',
       'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary']]
x_train = pd.concat([x_train, x_train_dummies], axis=1)

#y_train 전처리
y = y_train[['Exited']]

#x_test 전처리
x_test_dummies = pd.get_dummies(x_test_data[['Geography', 'Gender']])
x_test = x_test_data[['CreditScore', 'Age',
       'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary']]
x_test = pd.concat([x_test, x_test_dummies], axis=1)

#모델 학습
X_train, X_validation, y_train, y_validation = train_test_split(x_train, y, test_size=0.3, random_state=123)
model = RandomForestClassifier()
model.fit(X_train, y_train)

#모델 score
model.predict(X_train)
model.predict(X_validation)
model.predict_proba(X_train)[:,1]
model.predict_proba(X_Validation)[:,1]

print('train accuracy : ', accuracy_score(y_train, model.predict(X_train)))
print('validation accuracy : ', accuracy_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------------------------')
print('train f1_score : ', f1_score(y_train, model.predict(X_train)))
print('validation f1_score', f1_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------------------------')
print('train recall_score : ', recall_score(y_train, model.predict(X_train)))
print('validation recall_score', recall_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------------------------')
print('train precision_score : ', precision_score(y_train, model.predict(X_train)))
print('validation precision_score', precision_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------------------------')
print('train auc : ', roc_auc_score(y_train, model.predict_proba(X_train)[:,1]))
print('validation auc', roc_auc_score(y_validation, model.predict_proba(X_validation)[:,1]))

#test데이터
model.predict(x_test)
model.predict_proba(x_test)[:,1]

display(pd.DataFrame({'CustomerId' : x_test_data.CustomerId, 
              'Exited' : model.predict(x_test)}))
display(pd.DataFrame({'CustomerId' : x_test_data.CustomerId,
             'Exited' : model.predict_proba(x_test)[:,1]}))

"""
pd.DataFrame({'CustomerId' : x_test_data.CustomerId, 
              'Exited' : model.predict(x_test)}).to_csv('1.csv', index=False)
pd.DataFrame({'CustomerId' : x_test_data.CustomerId,
             'Exited' : model.predict_proba(x_test)[:,1]}).to_csv('2.csv', index=False)
"""
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24004\374406228.py:29: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# train accuracy :  1.0
# validation accuracy :  0.8523076923076923
# --------------------------------------------------------------------
# train f1_score :  1.0
# validation f1_score 0.5324675324675325
# --------------------------------------------------------------------
# train recall_score :  1.0
# validation recall_score 0.41
# --------------------------------------------------------------------
# train precision_score :  1.0
# validation precision_score 0.7592592592592593
# --------------------------------------------------------------------
# train auc :  1.0
# validation auc 0.8411112903225805
#       CustomerId  Exited
# 0       15601012       1
# 1       15734762       1
# 2       15586757       0
# 3       15590888       0
# ...

# %% [markdown]
# ### 이직여부 판단 데이터

# %%
import pandas as pd

x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/HRdata/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/HRdata/y_train.csv")
x_test_data= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/HRdata/X_test.csv")


#print(x_train.info())
#print('-------------------------------------')
#print(x_train.nunique())
#print('-------------------------------------')
#print(x_train.isna().sum())

drop_columns = ['enrollee_id', 'city', 'experience']
x_train = x_train.drop(columns = drop_columns)
x_test = x_test_data.drop(columns = drop_columns)
y = y_train.drop(columns = 'enrollee_id')

#import sklearn
#print(sklearn.__all__)

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
x_train = pd.get_dummies(x_train)
x_test = pd.get_dummies(x_test)
x_test = x_test[x_train.columns]

X_train, X_validation, y_train, y_validation = train_test_split(x_train, y, test_size=0.3, random_state=123)
model = RandomForestClassifier()
model.fit(X_train, y_train)

#import sklearn.metrics
#print(dir(sklearn.metrics))

from sklearn.metrics import accuracy_score, f1_score, recall_score,roc_auc_score, precision_score

print('train accuracy : ',accuracy_score(y_train, model.predict(X_train)))
print('validation accuracy : ', accuracy_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------------------------')
print('train f1_score : ', f1_score(y_train, model.predict(X_train)))
print('validation f1_score : ', f1_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------------------------')
print('train recall_score : ', recall_score(y_train, model.predict(X_train)))
print('validation recall_score : ', recall_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------------------------')
print('train precision_score : ', precision_score(y_train, model.predict(X_train)))
print('validation precision_score : ', precision_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------------------------')
print('train auc : ', roc_auc_score(y_train, model.predict_proba(X_train)[:,1]))
print('validation auc : ', roc_auc_score(y_validation, model.predict_proba(X_validation)[:,1]))

#pd.DataFrame({'enrollee_id' : x_test_data['enrollee_id'],
             'target' : model.predict(x_test)}).to_csv('1.csv',index=False)
#pd.DataFrame({'enrollee_id' : x_test_data['enrollee_id'],
             'target' : model.predict_proba(x_test)[:,1]}).to_csv('2.csv', index=False)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24004\2975262059.py:30: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# train accuracy :  0.997361174850849
# validation accuracy :  0.7698072805139187
# --------------------------------------------------------------------
# train f1_score :  0.9947500570645973
# validation f1_score :  0.4736842105263158
# --------------------------------------------------------------------
# train recall_score :  0.9936160510715915
# validation recall_score :  0.4243421052631579
# --------------------------------------------------------------------
# train precision_score :  0.9958866544789763
# validation precision_score :  0.53601108033241
# --------------------------------------------------------------------
# train auc :  0.9998955605473047
# validation auc :  0.766609861898017
#       enrollee_id  target
# ...

# %% [markdown]
# ### 정시 배송 여부 판단

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_test.csv")


#display(x_train)
#display(y_train)
"""
print(x_train.info())
print('------------------')
print(x_train.nunique())
print('---------------------')
print(x_train.isna().sum())
"""

X = x_train.drop(columns='ID')
y = y_train.drop(columns='ID')
x_test_2 = x_test.drop(columns='ID')

X = pd.get_dummies(X)
x_test_2 = pd.get_dummies(x_test_2)
x_test_2 = x_test_2[X.columns]

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
#순서 기억
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=123)
model = RandomForestClassifier()
model.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score

print('train_accuracy_score : ', accuracy_score(y_train, model.predict(X_train)))
print('validation_accuracy_score : ', accuracy_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------')
print('train_f1_score : ', f1_score(y_train, model.predict(X_train)))
print('validation_f1_score : ', f1_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------')
print('train_recall_score : ', recall_score(y_train, model.predict(X_train)))
print('validation_recall_score : ', recall_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------')
print('train_precision_score : ', precision_score(y_train, model.predict(X_train)))
print('validation_precision_score : ', precision_score(y_validation, model.predict(X_validation)))
print('--------------------------------------------------')
print('train_auc : ', roc_auc_score(y_train, model.predict_proba(X_train)[:,1]))
print('validation_auc : ', roc_auc_score(y_validation, model.predict_proba(X_validation)[:,1]))

"""
pd.DataFrame({'ID' : x_test['ID'],
             'Reached.on.Time_Y.N' : model.predict(x_test_2)}).to_csv('1.csv', index=False)
pd.DataFrame({'ID' : x_test['ID'],
             'Reached.on.Time_Y.N' : model.predict_proba(x_test_2)[:,1]}).to_csv('2.csv', index=False)
"""
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24004\2670016914.py:31: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# train_accuracy_score :  1.0
# validation_accuracy_score :  0.6525252525252525
# --------------------------------------------------
# train_f1_score :  1.0
# validation_f1_score :  0.6875567665758401
# --------------------------------------------------
# train_recall_score :  1.0
# validation_recall_score :  0.6415254237288136
# --------------------------------------------------
# train_precision_score :  1.0
# validation_precision_score :  0.7407045009784736
# --------------------------------------------------
# train_auc :  0.9999999999999999
# validation_auc :  0.734989936440678
# ...

# %% [markdown]
# ### 성인 건강검진 데이터

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/smoke/x_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/smoke/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/smoke/x_test.csv")


#display(x_train.head())
#display(y_train.head())
"""
print(x_train.info())
print('------------------------')
print(x_train.nunique())
print('------------------------')
print(x_train.isna().sum())
"""

X = x_train.drop(columns='ID')
y = y_train.drop(columns='ID')
x_test_2 = x_test.drop(columns='ID')

X = pd.get_dummies(X)
x_test_2 = pd.get_dummies(x_test_2)
x_test_2 = x_test_2[X.columns]

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=123)
model = RandomForestClassifier()
model.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score

#score 하이퍼파라미터 공부
print('train accuracy score : ', accuracy_score(y_train, model.predict(X_train)))
print('validation accuracy score : ', accuracy_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train f1 score : ', f1_score(y_train, model.predict(X_train)))
print('validation f1 score : ', f1_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train recall score : ', recall_score(y_train, model.predict(X_train)))
print('validation recall score : ', recall_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train precision score : ', precision_score(y_train, model.predict(X_train)))
print('validation precision score : ', precision_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train auc : ', roc_auc_score(y_train, model.predict_proba(X_train)[:,1]))
print('validation auc : ', roc_auc_score(y_validation, model.predict_proba(X_validation)[:,1]))
"""
pd.DataFrame({'ID' : x_test['ID'],
             '흡연상태' : model.predict(x_test_2)}).to_csv('1.csv', index=False)

pd.DataFrame({'ID' : x_test['ID'],
             '흡연상태' : model.predict_proba(x_test_2)[:,1]}).to_csv('2.csv', index=False)
"""
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24004\32018683.py:31: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# train accuracy score :  0.9999679353576811
# validation accuracy score :  0.7578183450546162
# ------------------------------------
# train f1 score :  0.9999562994362629
# validation f1 score :  0.6809894550113333
# ------------------------------------
# train recall score :  0.9999126026918371
# validation recall score :  0.7036659877800407
# ------------------------------------
# train precision score :  1.0
# validation precision score :  0.6597288523964101
# ------------------------------------
# train auc :  1.0
# validation auc :  0.8371957655008697
# ...

# %% [markdown]
# ### 비행탑승 경험 만족도 데이터

# %%
#test 데이터에 대해서 neutral or dissatisfied라고 예측할 확률을 구하고
#그 확률 값을 제출하라

import pandas as pd

x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/x_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/x_test.csv")


#display(x_train)
#display(y_train)
#display(x_test)
"""
print(x_train.info())
print('----------------------')
print(x_train.nunique())
print('----------------------')
print(x_train.isna().sum())
print('----------------------')
print(x_test.isna().sum())
"""
A_median = x_train['Arrival Delay in Minutes'].median()
x_train['Arrival Delay in Minutes'] = x_train['Arrival Delay in Minutes'].fillna(A_median)
x_test['Arrival Delay in Minutes'] = x_train['Arrival Delay in Minutes'].fillna(A_median)

X = x_train.drop(columns=['ID', 'id'])
y = y_train.drop(columns='ID')
x_test_2 = x_test.drop(columns=['ID', 'id'])
X = pd.get_dummies(X)
x_test_2 = pd.get_dummies(x_test_2)
x_test_2 = x_test_2[X.columns]
dic = {'neutral or dissatisfied':1 , 'satisfied':0}
y = y_train['satisfaction'].map(dic)


from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=123)
model = RandomForestClassifier()
model.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score

print('train accuracy_score : ', accuracy_score(y_train, model.predict(X_train)))
print('validation accuracy_score : ', accuracy_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train f1_score : ', f1_score(y_train, model.predict(X_train)))
print('validation f1_score : ', f1_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train recall_score : ', recall_score(y_train, model.predict(X_train)))
print('validation recall_score : ', recall_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train precision_score : ', precision_score(y_train, model.predict(X_train)))
print('validation precision_score : ', precision_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train auc : ', roc_auc_score(y_train, model.predict_proba(X_train)[:,1]))
print('validation auc : ', roc_auc_score(y_validation, model.predict_proba(X_validation)[:,1]))

#pd.DataFrame({'ID' : x_test['ID'],
#             'neutral or dissatisfied probabaility' : model.predict_proba(x_test_2)[:,1]}).to_csv(index=False)
# Out:
# train accuracy_score :  1.0
# validation accuracy_score :  0.9623050086217267
# ------------------------------------
# train f1_score :  1.0
# validation f1_score :  0.9671856454653356
# ------------------------------------
# train recall_score :  1.0
# validation recall_score :  0.9802575714690065
# ------------------------------------
# train precision_score :  1.0
# validation precision_score :  0.9544577649166323
# ------------------------------------
# train auc :  1.0
# validation auc :  0.9935088030315871
#            ID  neutral or dissatisfied probabaility
# 0           1                                  0.72
# 1          16                                  0.97
# 2          17                                  1.00
# 3          25                                  0.97
# 4          27                                  0.10
# ...       ...                                   ...
# 20776  103895                                  0.95
# ...

# %% [markdown]
# ### 약물 데이터

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/drug/x_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/drug/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/drug/x_test.csv")

X = x_train.drop(columns='ID')
y = y_train.drop(columns='ID')
x_test_2 = x_test.drop(columns='ID')

X = pd.get_dummies(X)
y = pd.get_dummies(y)
x_test_2 = pd.get_dummies(x_test_2)
x_test_2 = x_test_2[X.columns]

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=123)
model = RandomForestClassifier()
model.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score


print('train accuracy_score : ', accuracy_score(y_train, model.predict(X_train)))
print('validation accuracy_score : ', accuracy_score(y_validation, model.predict(X_validation)))
print('------------------------------------')
print('train f1_score : ', f1_score(y_train, model.predict(X_train),average='micro'))
print('validation f1_score : ', f1_score(y_validation, model.predict(X_validation),average='micro'))
print('------------------------------------')
print('train recall_score : ', recall_score(y_train, model.predict(X_train), average='micro'))
print('validation recall_score : ', recall_score(y_validation, model.predict(X_validation), average='micro'))
print('------------------------------------')
print('train precision_score : ', precision_score(y_train, model.predict(X_train), average='micro'))
print('validation precision_score : ', precision_score(y_validation, model.predict(X_validation), average='micro'))
print('------------------------------------')
print('train auc : ', roc_auc_score(y_train, model.predict_proba(X_train)[:,1]),multi_class='ovr')
print('validation auc : ', roc_auc_score(y_validation, model.predict_proba(X_validation)[:,1]),multi_class='ovr')

# %% [markdown]
# ## 회귀

# %% [markdown]
# ### 학생성적 예측 데이터

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/studentscore/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/studentscore/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/studentscore/X_test.csv")

"""
print(x_train.info())
print(x_train.nunique())
print(x_train.isna().sum())
"""

X = x_train.drop(columns = 'StudentID')
y = y_train.drop(columns = 'StudentID')
x_test_2 = x_test.drop(columns = 'StudentID')

X = pd.get_dummies(X)
x_test_2 = pd.get_dummies(x_test_2)
x_test_2 = x_test_2[X.columns]

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

X_train, X_validation,y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=123)
model = RandomForestRegressor(random_state=123)
model.fit(X_train, y_train)

import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

print('train mse : ', mean_squared_error(y_train, model.predict(X_train)))
print('validation mse ; ', mean_squared_error(y_validation, model.predict(X_validation)))
print('-----------------------------------------------')
print('train mae : ', mean_absolute_error(y_train, model.predict(X_train)))
print('validation mae : ', mean_absolute_error(y_validation, model.predict(X_validation)))
print('-----------------------------------------------')
print('train mape : ', mean_absolute_percentage_error(y_train, model.predict(X_train)))
print('validation mape : ', mean_absolute_percentage_error(y_validation, model.predict(X_validation)))
print('-----------------------------------------------')
print('train rmse : ', np.sqrt(mean_squared_error(y_train, model.predict(X_train))))
print('validation rmse : ', np.sqrt(mean_squared_error(y_validation, model.predict(X_validation))))
print('-----------------------------------------------')
print('train r2 score : ', r2_score(y_train, model.predict(X_train)))
print('validation r2 score : ', r2_score(y_validation, model.predict(X_validation)))

pd.DataFrame({'StudentID' : x_test['StudentID'], 'G3' : model.predict(x_test_2)})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24004\2342908912.py:26: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# train mse :  0.2930954419831223
# validation mse ;  1.9920806041666668
# -----------------------------------------------
# train mae :  0.33658790436005626
# validation mae :  0.8490629084967318
# -----------------------------------------------
# train mape :  221474488004232.6
# validation mape :  646619770027852.1
# -----------------------------------------------
# train rmse :  0.5413828977564052
# validation rmse :  1.4114108559050644
# -----------------------------------------------
# train r2 score :  0.9801088951755286
# validation r2 score :  0.8572734580768119
#      StudentID         G3
# 0         1000  16.275000
# 1         1008  11.040000
# 2         1013  14.360000
# 3         1014   7.400000
# ...

# %% [markdown]
# ### 중고차 가격 예측 데이터

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/X_test.csv")
"""
print(x_train.info())
print(x_train.nunique())
print(x_train.isna().sum())
print(y_train.info())
print(x_test.info())
"""

X = x_train.drop(columns='carID')
y = y_train.drop(columns='carID')
x_test_2 = x_test.drop(columns='carID')

X = pd.get_dummies(X)
x_test_2 = pd.get_dummies(x_test_2)
x_test_2['model_ M6'] = 0
x_test_2 = x_test_2[X.columns]

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=123)
model = RandomForestRegressor(random_state=123)
model.fit(X_train, y_train)

import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

print('train mse : ' ,mean_squared_error(y_train, model.predict(X_train)))
print('validation mse : ', mean_squared_error(y_validation, model.predict(X_validation)))
print('-------------------------------------------------')
print('train mae : ' ,mean_absolute_error(y_train, model.predict(X_train)))
print('validation mae : ' ,mean_absolute_error(y_validation, model.predict(X_validation)))
print('-------------------------------------------------')
print('train mape : ' ,mean_absolute_percentage_error(y_train, model.predict(X_train)))
print('validation mape : ' ,mean_absolute_percentage_error(y_validation, model.predict(X_validation)))
print('-------------------------------------------------')
print('train rmse : ' ,np.sqrt(mean_squared_error(y_train, model.predict(X_train))))
print('validation rmse : ' ,np.sqrt(mean_squared_error(y_validation, model.predict(X_validation))))
print('-------------------------------------------------')
print('train r2 score : ' ,r2_score(y_train, model.predict(X_train)))
print('validation r2 score : ', r2_score(y_validation, model.predict(X_validation)))

pd.DataFrame({'carID' : x_test['carID'], 'price' : model.predict(x_test_2)})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24004\1614644613.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# train mse :  1860173.9678866281
# validation mse :  14486032.936622743
# -------------------------------------------------
# train mae :  747.7480786530259
# validation mae :  2044.3052747892416
# -------------------------------------------------
# train mape :  0.036011141037522156
# validation mape :  0.10130146461918456
# -------------------------------------------------
# train rmse :  1363.8819479290091
# validation rmse :  3806.052145809716
# -------------------------------------------------
# train r2 score :  0.9930196443434194
# validation r2 score :  0.9473759273457071
#       carID     price
# 0     12000  39248.82
# 1     12001  25089.56
# 2     12004  54954.27
# 3     12013  14912.74
# 4     12017  50549.39
# ...
