# %%
import pandas as pd

# %%
Teddy_df = pd.read_csv('./Teddy_df.csv', index_col=0)
user_1 = pd.read_csv('./user_1.csv', index_col=0)
user_2 = pd.read_csv('./user_2.csv', index_col=0)
user_3 = pd.read_csv('./user_3.csv', index_col=0)
user_4 = pd.read_csv('./user_4.csv', index_col=0)
user_5 = pd.read_csv('./user_5.csv', index_col=0)
user_6 = pd.read_csv('./user_6.csv', index_col=0)
user_7 = pd.read_csv('./user_7.csv', index_col=0)
user_8 = pd.read_csv('./user_8.csv', index_col=0)
user_9 = pd.read_csv('./user_9.csv', index_col=0)
user_10 = pd.read_csv('./user_10.csv', index_col=0)
user_11 = pd.read_csv('./user_11.csv', index_col=0)
user_12 = pd.read_csv('./user_12.csv', index_col=0)
user_13 = pd.read_csv('./user_13.csv', index_col=0)
user_14 = pd.read_csv('./user_14.csv', index_col=0)
user_15 = pd.read_csv('./user_15.csv', index_col=0)
user_16 = pd.read_csv('./user_16.csv', index_col=0)
user_17 = pd.read_csv('./user_17.csv', index_col=0)
user_18 = pd.read_csv('./user_18.csv', index_col=0)
user_19 = pd.read_csv('./user_19.csv', index_col=0)
user_20 = pd.read_csv('./user_20.csv', index_col=0)

# %%
Teddy_df = Teddy_df[['KDA']]
Teddy_df.rename(columns={'KDA':'Teddy'}, inplace=True)
Teddy_df
# Out:
#           Teddy
# Name
# 루시안    3.750000
# 바루스    2.400000
# 아리     1.218750
# 아칼리    3.263158
# 아펠리오스  3.545455
# 이렐리아   2.333333
# 자야     3.045455
# 제리     3.078947
# 제이스    3.083333
# 카이사    2.571429

# %%
user_1 = user_1[['KDA']]
user_1.rename(columns={'KDA':'user_1'}, inplace=True)
user_1
# Out:
#          user_1
# Name
# 비에고    1.714286
# 시비르    2.000000
# 아펠리오스  4.600000
# 이즈리얼   1.615385
# 자야     1.906250
# 제리     3.218487
# 카이사    3.774194

# %%
user_2 = user_2[['KDA']]
user_2.rename(columns={'KDA':'user_2'}, inplace=True)
user_2
# Out:
#             user_2
# Name
# 노틸러스      1.941176
# 닐라        2.630769
# 드레이븐      3.882353
# 레나타 글라스크  3.363636
# 레오나       1.400000
# 비에고       2.756098
# 사미라       2.648649
# 스웨인       2.608696
# 시비르       2.333333
# 알리스타      2.363636
# 이즈리얼      1.333333
# 자르반 4세    2.500000
# 자야        2.960000
# 카르마       6.600000
# 카이사       3.355556
# 칼리스타      1.600000
# 케이틀린      4.200000
# 트리스타나     1.423077
# 트린다미어     2.600000

# %%
user_3 = user_3[['KDA']]
user_3.rename(columns={'KDA':'user_3'}, inplace=True)
user_3
# Out:
#          user_3
# Name
# 닐라     2.634146
# 드레이븐   2.461538
# 라칸     1.950000
# 바루스    3.750000
# 세트     0.875000
# 알리스타   1.833333
# 제리     2.461538
# 카이사    2.485714
# 칼리스타   3.210227
# 케이틀린   1.000000
# 트리스타나  1.904762

# %%
user_4 = user_4[['KDA']]
user_4.rename(columns={'KDA':'user_4'}, inplace=True)
user_4
# Out:
#          user_4
# Name
# 노틸러스   2.666667
# 녹턴     3.090909
# 닐라     1.142857
# 라칸     3.000000
# 렐      2.875000
# 루시안    4.200000
# 리 신    4.571429
# 아펠리오스  2.333333
# 이즈리얼   3.615385
# 자야     2.390625
# 제리     3.329670
# 직스     4.000000
# 카이사    3.410959
# 칼리스타   3.296296
# 케이틀린   3.875000

# %%
user_5 = user_5[['KDA']]
user_5.rename(columns={'KDA':'user_5'}, inplace=True)
user_5
# Out:
#         user_5
# Name
# 노틸러스  2.217391
# 닐라    2.000000
# 라칸    3.205479
# 브라움   3.090909
# 신지드   2.300000
# 알리스타  1.923077
# 자야    2.425000
# 제리    2.659574
# 카르마   2.380952
# 카이사   3.200000
# 칼리스타  2.798450

# %%
user_6 = user_6[['KDA']]
user_6.rename(columns={'KDA':'user_6'}, inplace=True)
user_6
# Out:
#         user_6
# Name
# 말파이트  6.058824
# 바루스   2.857143
# 소라카   2.636364
# 시비르   3.500000
# 이즈리얼  4.800000
# 자야    3.400000
# 제리    3.737589
# 카이사   3.806452
# 케이틀린  2.384615

# %%
user_7 = user_7[['KDA']]
user_7.rename(columns={'KDA':'user_7'}, inplace=True)
user_7
# Out:
#          user_7
# Name
# 니코     2.307692
# 닐라     3.806452
# 라칸     1.500000
# 루시안    2.222222
# 벡스     2.400000
# 사미라    2.375000
# 시비르    7.333333
# 아펠리오스  2.923077
# 이즈리얼   2.600000
# 자야     2.096154
# 제리     3.024691
# 카이사    3.232558
# 케이틀린   1.444444

# %%
user_8 = user_8[['KDA']]
user_8.rename(columns={'KDA':'user_8'}, inplace=True)
user_8
# Out:
#          user_8
# Name
# 닐라     1.388889
# 드레이븐   2.553191
# 루시안    2.034483
# 미스 포츈  7.000000
# 세나     4.400000
# 시비르    4.000000
# 아펠리오스  2.312500
# 야스오    1.000000
# 이즈리얼   1.314286
# 자야     3.166667
# 제리     2.870130
# 진      1.750000
# 카시오페아  1.625000
# 카이사    2.515152
# 칼리스타   2.600000
# 케이틀린   2.388889
# 트리스타나  3.500000

# %%
user_9 = user_9[['KDA']]
user_9.rename(columns={'KDA':'user_9'}, inplace=True)
user_9
# Out:
#            user_9
# Name
# 닐라       2.545455
# 바루스      2.785714
# 베인       7.833333
# 뽀삐       2.200000
# 아펠리오스    1.545455
# 알리스타     3.296296
# 이즈리얼     4.400000
# 자르반 4세   4.222222
# 자야       3.120370
# 제라스     10.500000
# 제리       3.731707
# 카이사      3.064935
# 칼리스타     2.333333
# 크산테      2.826087

# %%
user_10 = user_10[['KDA']]
user_10.rename(columns={'KDA':'user_10'}, inplace=True)
user_10
# Out:
#         user_10
# Name
# 드레이븐   5.400000
# 라칸     3.977778
# 렐      5.750000
# 아펠리오스  3.482759
# 알리스타   1.888889
# 애쉬     1.166667
# 이즈리얼   4.666667
# 자야     4.480000
# 제리     2.800000
# 카이사    4.538462

# %%
user_11 = user_11[['KDA']]
user_11.rename(columns={'KDA':'user_11'}, inplace=True)
user_11
# Out:
#         user_11
# Name
# 니달리    4.315789
# 루시안    1.526316
# 리 신    6.000000
# 미스 포츈  3.000000
# 비에고    3.111111
# 시비르    3.727273
# 아펠리오스  3.230769
# 이즈리얼   4.179245
# 제리     1.666667
# 카이사    2.772727
# 칼리스타   2.076923
# 탈리야    1.312500

# %%
user_12 = user_12[['KDA']]
user_12.rename(columns={'KDA':'user_12'}, inplace=True)
user_12
# Out:
#         user_12
# Name
# 니코     1.315789
# 닐라     2.947368
# 루시안    2.833333
# 리 신    1.181818
# 바루스    6.166667
# 베인     2.678571
# 벡스     1.846154
# 볼리베어   1.400000
# 사미라    2.615385
# 아펠리오스  2.535211
# 애쉬     1.600000
# 자야     2.583333
# 제리     2.250000
# 제이스    2.800000
# 진      3.523810
# 징크스    3.526316
# 카이사    3.225352

# %%
user_13 = user_13[['KDA']]
user_13.rename(columns={'KDA':'user_13'}, inplace=True)
user_13
# Out:
#         user_13
# Name
# 노틸러스   2.833333
# 말자하    9.333333
# 애쉬     2.742857
# 이즈리얼   3.395062
# 트리스타나  1.400000

# %%
user_14 = user_14[['KDA']]
user_14.rename(columns={'KDA':'user_14'}, inplace=True)
user_14
# Out:
#         user_14
# Name
# 닐라     0.842105
# 드레이븐   2.947368
# 미스 포츈  2.000000
# 바루스    2.000000
# 아펠리오스  1.500000
# 이즈리얼   2.349206
# 자야     2.060000
# 자이라    3.200000
# 제리     3.474359
# 제이스    3.777778
# 직스     1.947368
# 카이사    2.972222
# 케이틀린   0.714286
# 크산테    3.153846
# 트리스타나  3.000000
# 파이크    2.625000

# %%
user_15 = user_15[['KDA']]
user_15.rename(columns={'KDA':'user_15'}, inplace=True)
user_15
# Out:
#         user_15
# Name
# 닐라     1.942857
# 드레이븐   0.892857
# 루시안    3.294118
# 알리스타   0.888889
# 이즈리얼   3.095238
# 자야     3.983607
# 제리     1.720000
# 진      3.800000
# 카이사    4.136364
# 케이틀린   3.178571
# 트린다미어  6.000000

# %%
user_16 = user_16[['KDA']]
user_16.rename(columns={'KDA':'user_16'}, inplace=True)
user_16
# Out:
#           user_16
# Name
# 니코       2.166667
# 벡스       0.647059
# 아우렐리온 솔  2.692308
# 아펠리오스    2.862069
# 이즈리얼     2.821429
# 자야       1.888889
# 제리       3.000000
# 직스       7.500000
# 카이사      3.382812
# 코르키      3.321429

# %%
user_17 = user_17[['KDA']]
user_17.rename(columns={'KDA':'user_17'}, inplace=True)
user_17
# Out:
#        user_17
# Name
# 노틸러스  3.750000
# 드레이븐  0.750000
# 벡스    0.700000
# 이즈리얼  8.000000
# 자야    2.553571
# 제리    2.829060
# 제이스   4.416667
# 카이사   3.071429

# %%
user_18 = user_18[['KDA']]
user_18.rename(columns={'KDA':'user_18'}, inplace=True)
user_18
# Out:
#          user_18
# Name
# 라칸      4.150943
# 루시안     1.666667
# 말파이트    3.500000
# 바루스    11.000000
# 사미라     4.866667
# 사이온     3.736842
# 사일러스    4.692308
# 시비르     1.428571
# 아펠리오스   2.666667
# 야스오     1.700000
# 요네      1.909091
# 이즈리얼    3.000000
# 자야      2.600000
# 제리      3.253165
# 진       2.250000
# 카이사     4.260870
# 킨드레드    1.187500

# %%
user_19 = user_19[['KDA']]
user_19.rename(columns={'KDA':'user_19'}, inplace=True)
user_19
# Out:
#        user_19
# Name
# 루시안   2.057143
# 카이사   6.600000

# %%
user_20 = user_20[['KDA']]
user_20.rename(columns={'KDA':'user_20'}, inplace=True)
user_20
# Out:
#         user_20
# Name
# 리 신    2.866667
# 비에고    2.700000
# 아펠리오스  1.625000
# 이즈리얼   0.846154
# 자야     4.362319
# 제리     2.561404
# 직스     0.363636
# 카이사    2.513889
# 칼리스타   2.785714

# %%
user = user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10, user_11, user_12, user_13, user_14, user_15, user_16, user_17, user_18, user_19,user_20

# %%
concat_df = pd.concat([Teddy_df, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10, user_11, user_12, user_13, user_14, user_15, user_16, user_17, user_18, user_19,user_20], axis=1)
concat_df
# Out:
#           Teddy  user_1  user_2  user_3    user_4  user_5    user_6    user_7  \
# Name
# 루시안    3.750000     NaN     NaN     NaN  4.200000     NaN       NaN  2.222222
# 바루스    2.400000     NaN     NaN    3.75       NaN     NaN  2.857143       NaN
# 아리     1.218750     NaN     NaN     NaN       NaN     NaN       NaN       NaN
# 아칼리    3.263158     NaN     NaN     NaN       NaN     NaN       NaN       NaN
# 아펠리오스  3.545455     4.6     NaN     NaN  2.333333     NaN       NaN  2.923077
# ...         ...     ...     ...     ...       ...     ...       ...       ...
# 코르키         NaN     NaN     NaN     NaN       NaN     NaN       NaN       NaN
# 사이온         NaN     NaN     NaN     NaN       NaN     NaN       NaN       NaN
# 사일러스        NaN     NaN     NaN     NaN       NaN     NaN       NaN       NaN
# 요네          NaN     NaN     NaN     NaN       NaN     NaN       NaN       NaN
# 킨드레드        NaN     NaN     NaN     NaN       NaN     NaN       NaN       NaN
#
#          user_8    user_9   user_10   user_11   user_12  user_13  user_14  \
# Name
# 루시안    2.034483       NaN       NaN  1.526316  2.833333      NaN      NaN
# 바루스         NaN  2.785714       NaN       NaN  6.166667      NaN      2.0
# 아리          NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 아칼리         NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 아펠리오스  2.312500  1.545455  3.482759  3.230769  2.535211      NaN      1.5
# ...         ...       ...       ...       ...       ...      ...      ...
# 코르키         NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 사이온         NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 사일러스        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 요네          NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 킨드레드        NaN       NaN       NaN       NaN       NaN      NaN      NaN
#
#         user_15   user_16  user_17    user_18   user_19  user_20
# Name
# 루시안    3.294118       NaN      NaN   1.666667  2.057143      NaN
# 바루스         NaN       NaN      NaN  11.000000       NaN      NaN
# 아리          NaN       NaN      NaN        NaN       NaN      NaN
# 아칼리         NaN       NaN      NaN        NaN       NaN      NaN
# 아펠리오스       NaN  2.862069      NaN   2.666667       NaN    1.625
# ...         ...       ...      ...        ...       ...      ...
# 코르키         NaN  3.321429      NaN        NaN       NaN      NaN
# 사이온         NaN       NaN      NaN   3.736842       NaN      NaN
# 사일러스        NaN       NaN      NaN   4.692308       NaN      NaN
# 요네          NaN       NaN      NaN   1.909091       NaN      NaN
# 킨드레드        NaN       NaN      NaN   1.187500       NaN      NaN
#
# [62 rows x 21 columns]

# %%
KDA_df = concat_df.drop(['아리', '아칼리', '이렐리아', '제이스', '비에고', '노틸러스', '레나타 글라스크', '레오나', '스웨인', '알리스타', '자르반 4세', '카르마', '트린다미어', '라칸', '세트', '녹턴', '렐', '리 신', '브라움', '신지드', '말파이트', '소라카', '니코', '벡스', '야스오', '카시오페아', '뽀삐', '제라스', '크산테', '니달리', '탈리야', '볼리베어', '말자하', '자이라', '파이크','사이온', '사일러스', '요네', '킨드레드', '아우렐리온 솔', '코르키', '징크스', '애쉬', '베인', '세나', '진', '미스 포츈', '사미라', '직스', '트리스타나'])
KDA_df.T
# Out:
# Name          루시안        바루스     아펠리오스        자야        제리       카이사  \
# Teddy    3.750000   2.400000  3.545455  3.045455  3.078947  2.571429
# user_1        NaN        NaN  4.600000  1.906250  3.218487  3.774194
# user_2        NaN        NaN       NaN  2.960000       NaN  3.355556
# user_3        NaN   3.750000       NaN       NaN  2.461538  2.485714
# user_4   4.200000        NaN  2.333333  2.390625  3.329670  3.410959
# user_5        NaN        NaN       NaN  2.425000  2.659574  3.200000
# user_6        NaN   2.857143       NaN  3.400000  3.737589  3.806452
# user_7   2.222222        NaN  2.923077  2.096154  3.024691  3.232558
# user_8   2.034483        NaN  2.312500  3.166667  2.870130  2.515152
# user_9        NaN   2.785714  1.545455  3.120370  3.731707  3.064935
# user_10       NaN        NaN  3.482759  4.480000  2.800000  4.538462
# user_11  1.526316        NaN  3.230769       NaN  1.666667  2.772727
# user_12  2.833333   6.166667  2.535211  2.583333  2.250000  3.225352
# user_13       NaN        NaN       NaN       NaN       NaN       NaN
# user_14       NaN   2.000000  1.500000  2.060000  3.474359  2.972222
# user_15  3.294118        NaN       NaN  3.983607  1.720000  4.136364
# user_16       NaN        NaN  2.862069  1.888889  3.000000  3.382812
# user_17       NaN        NaN       NaN  2.553571  2.829060  3.071429
# user_18  1.666667  11.000000  2.666667  2.600000  3.253165  4.260870
# user_19  2.057143        NaN       NaN       NaN       NaN  6.600000
# user_20       NaN        NaN  1.625000  4.362319  2.561404  2.513889
#
# Name          시비르      이즈리얼        닐라      드레이븐      칼리스타      케이틀린
# Teddy         NaN       NaN       NaN       NaN       NaN       NaN
# user_1   2.000000  1.615385       NaN       NaN       NaN       NaN
# user_2   2.333333  1.333333  2.630769  3.882353  1.600000  4.200000
# user_3        NaN       NaN  2.634146  2.461538  3.210227  1.000000
# user_4        NaN  3.615385  1.142857       NaN  3.296296  3.875000
# user_5        NaN       NaN  2.000000       NaN  2.798450       NaN
# user_6   3.500000  4.800000       NaN       NaN       NaN  2.384615
# user_7   7.333333  2.600000  3.806452       NaN       NaN  1.444444
# user_8   4.000000  1.314286  1.388889  2.553191  2.600000  2.388889
# user_9        NaN  4.400000  2.545455       NaN  2.333333       NaN
# user_10       NaN  4.666667       NaN  5.400000       NaN       NaN
# user_11  3.727273  4.179245       NaN       NaN  2.076923       NaN
# user_12       NaN       NaN  2.947368       NaN       NaN       NaN
# user_13       NaN  3.395062       NaN       NaN       NaN       NaN
# user_14       NaN  2.349206  0.842105  2.947368       NaN  0.714286
# user_15       NaN  3.095238  1.942857  0.892857       NaN  3.178571
# user_16       NaN  2.821429       NaN       NaN       NaN       NaN
# user_17       NaN  8.000000       NaN  0.750000       NaN       NaN
# user_18  1.428571  3.000000       NaN       NaN       NaN       NaN
# user_19       NaN       NaN       NaN       NaN       NaN       NaN
# user_20       NaN  0.846154       NaN       NaN  2.785714       NaN

# %%
#pd.options.display.max_columns=22
#pd.options.display.max_rows=22

# %%
#KDA_df.T.to_csv('./KDA_df.csv')

# %%
import numpy as np
import pandas as pd

np.random.seed(5)

def predict(Theta, X):
    return Theta @ X

def cost(prediction, R):
    return np.nansum((prediction - R) ** 2)



def initialize(R, num_features):
    num_users, num_items = R.shape
    
    Theta = np.random.rand(num_users, num_features)
    X = np.random.rand(num_features, num_items)
    
    return Theta, X

def gradient_descent(R, Theta, X, iteration, alpha, lambda_):
    num_user, num_items = R.shape
    num_features = len(X)
    costs = []

    for _ in range(iteration) :
        prediction = predict(Theta, X)
        error = prediction - R
        costs.append(cost(prediction, R))

        for i in range(num_user):
            for j in range(num_items):
                if not np.isnan(R[i][j]):
                    for k in range(num_features):
                        Theta[i][k] -= alpha * (np.nansum(error[i, :]*X[k, :]) + lambda_*Theta[i][k])
                        X[k][j] -= alpha * (np.nansum(error[:,j]*Theta[:,k]) + lambda_*X[k][j])

    return Theta, X, costs

# %%
KDA_df = pd.read_csv('./KDA_df.csv', index_col=0)

for row in KDA_df.values:
    row -= np.nanmean(row)
    
R = KDA_df.values

Theta, X = initialize(R, 5)

Theta, X, costs = gradient_descent(R, Theta, X, 200, 0.001, 0.01)

# %%
KDA_df
# Out:
#               루시안       바루스     아펠리오스        자야        제리       카이사       시비르  \
# Teddy    0.684786 -0.665214  0.480240 -0.019760  0.013733 -0.493786       NaN
# user_1        NaN       NaN  1.747614 -0.946136  0.366101  0.921808 -0.852386
# user_2        NaN       NaN       NaN  0.173082       NaN  0.568638 -0.453585
# user_3        NaN  1.178119       NaN       NaN -0.110342 -0.086166       NaN
# user_4   1.133986       NaN -0.732681 -0.675389  0.263656  0.344945       NaN
# user_5        NaN       NaN       NaN -0.191605  0.042970  0.583395       NaN
# user_6        NaN -0.640828       NaN -0.097971  0.239617  0.308480  0.002029
# user_7  -0.964770       NaN -0.263916 -1.090839 -0.162301  0.045566  4.146341
# user_8  -0.433170       NaN -0.155153  0.699013  0.402477  0.047498  1.532347
# user_9        NaN -0.155157 -1.395417  0.179499  0.790836  0.124064       NaN
# user_10       NaN       NaN -0.745223  0.252019 -1.427981  0.310480       NaN
# user_11 -1.213673       NaN  0.490781       NaN -1.073322  0.032739  0.987284
# user_12 -0.386847  2.946486 -0.684969 -0.636847 -0.970181  0.005171       NaN
# user_13       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# user_14       NaN -0.095505 -0.595505 -0.035505  1.378854  0.876717       NaN
# user_15  0.513666       NaN       NaN  1.203155 -1.060451  1.355912       NaN
# user_16       NaN       NaN  0.071029 -0.902151  0.208960  0.591773       NaN
# user_17       NaN       NaN       NaN -0.887241 -0.611752 -0.369383       NaN
# user_18 -2.067826  7.265508 -1.067826 -1.134492 -0.481328  0.526377 -2.305921
# user_19 -2.271429       NaN       NaN       NaN       NaN  2.271429       NaN
# user_20       NaN       NaN -0.824080  1.913239  0.112324  0.064809       NaN
#
#              이즈리얼        닐라      드레이븐      칼리스타      케이틀린
# Teddy         NaN       NaN       NaN       NaN       NaN
# user_1  -1.237001       NaN       NaN       NaN       NaN
# user_2  -1.453585 -0.156149  1.095435 -1.186918  1.413082
# user_3        NaN  0.062266 -0.110342  0.638347 -1.571881
# user_4   0.549371 -1.923157       NaN  0.230282  0.808986
# user_5        NaN -0.616605       NaN  0.181845       NaN
# user_6   1.302029       NaN       NaN       NaN -1.113356
# user_7  -0.586992  0.619459       NaN       NaN -1.742548
# user_8  -1.153368 -1.078764  0.085538  0.132347 -0.078764
# user_9   1.459129 -0.395417       NaN -0.607538       NaN
# user_10  0.438686       NaN  1.172019       NaN       NaN
# user_11  1.439257       NaN       NaN -0.663066       NaN
# user_12       NaN -0.272812       NaN       NaN       NaN
# user_13  0.000000       NaN       NaN       NaN       NaN
# user_14  0.253701 -1.253400  0.851863       NaN -1.381220
# user_15  0.314787 -0.837594 -1.887594       NaN  0.398120
# user_16  0.030389       NaN       NaN       NaN       NaN
# user_17  4.559188       NaN -2.690812       NaN       NaN
# user_18 -0.734492       NaN       NaN       NaN       NaN
# user_19       NaN       NaN       NaN       NaN       NaN
# user_20 -1.602926       NaN       NaN  0.336634       NaN

# %%
Theta
# Out:
# array([[-0.35582353,  0.08576529,  0.44736632,  0.0108374 , -0.26840527],
#        [ 0.23015295, -0.69243648, -0.60557366,  0.50741431,  0.35596571],
#        [ 0.81216184, -0.21916638, -0.07660745, -0.17083667,  0.31118804],
#        [-0.36858498,  0.10382251,  0.45295136,  0.81183008,  0.28693898],
#        [ 0.98789389,  0.25114101,  0.57353496,  0.43074454, -0.59664402],
#        [ 0.29660522,  0.48688794,  0.56429725,  0.74671976,  0.09225497],
#        [-0.43086861,  0.32280726,  0.09867478,  0.36707905, -0.25871164],
#        [-0.68044813,  0.70339891,  0.21560268,  0.12284271,  1.88813021],
#        [ 0.10362979,  0.57596771, -0.31942579, -0.21365291,  0.33994222],
#        [-0.38697064,  0.9212242 ,  0.2737821 ,  0.35079544, -0.03252543],
#        [ 1.00585248,  0.1965973 ,  0.79873846,  0.42726741,  0.55882649],
#        [-0.29222691,  0.09461381,  0.78654176,  0.81250642,  1.05645071],
#        [ 0.36764742,  0.42928847,  1.01305983,  0.56303351,  0.81161504],
#        [ 0.06677025,  0.3662846 ,  0.07364956,  0.5649645 ,  0.76809659],
#        [-0.28118469,  0.63058129, -0.63521449,  0.70653496, -0.08150315],
#        [ 0.22640633,  1.63570808,  0.7848767 , -0.5605653 ,  0.64345005],
#        [ 0.79952036, -0.18021161,  0.23630316,  0.82376426,  0.14638354],
#        [-0.31676991,  0.59219367,  1.674906  ,  0.68813519, -0.71767209],
#        [ 1.91622922, -0.39572513,  0.50358013,  1.70173152,  0.95616893],
#        [ 0.56095686,  1.02764348, -0.34959812,  0.96580784,  0.64949435],
#        [ 0.90181613,  0.71264268, -0.05188164, -0.69260329,  0.07814451]])

# %%
X
# Out:
# array([[ 0.06106919,  1.63417308, -0.44090559,  0.51161588, -0.1472579 ,
#          0.39960156, -0.76822714, -1.09779651, -0.93815999,  1.02901015,
#          0.03583584,  1.27751493],
#        [-0.20155986, -0.1806732 , -1.11170218,  0.73261265,  0.5395847 ,
#          0.76130525,  1.41798279,  0.23544618, -1.06033835, -0.65036479,
#         -0.05493681, -0.31473559],
#        [ 0.97553519,  0.41092567, -0.17885457, -0.40535129, -1.10096986,
#         -0.63446656, -0.15607766,  1.63399122,  0.45706372, -1.18641207,
#         -0.05339874,  0.07908386],
#        [-1.17704753,  1.3780629 , -0.13542964, -0.9083318 ,  0.60102248,
#          0.4655682 , -0.88049629,  0.93298486, -0.50320598,  0.90807757,
#          0.1337831 , -1.18146996],
#        [-0.70365984,  1.54041352,  0.19457174, -0.31284493, -0.50803089,
# user_15  0.290135 -1.012851 -1.757571 -0.413164  0.323466
# user_16  0.096690 -0.798821  1.524424  0.087338  0.083669
# user_17  4.541793 -0.238434 -2.646066  0.197993 -1.076075
# user_18 -0.686666 -1.568673  3.940077 -0.027582  0.341317
# user_19 -0.655630 -1.965812  1.718992 -0.105002 -0.952491
# user_20 -1.626771 -1.241281 -0.040523 -0.122773  1.720685

# %%
import matplotlib.pyplot as plt

plt.plot(costs)

# %%
import numpy as np


iterations = [100, 200, 300]  # 학습 반복 횟수 후보
alphas = [0.001, 0.01, 0.1]   # 학습률 후보
lambdas = [0.001, 0.01, 0.1]  # 정규화 가중치 후보

best_cost = np.inf 
best_hyperparameters = None

for iteration in iterations:
    for alpha in alphas:
        for lambda_ in lambdas:
       
            Theta, X = initialize(R, 5)
            Theta, X, costs = gradient_descent(R, Theta, X, iteration, alpha, lambda_)
            
         
            final_cost = costs[-1]
            
            
            if final_cost != 0 and final_cost < best_cost:
                best_cost = final_cost
                best_hyperparameters = (iteration, alpha, lambda_)


print(f"Best Hyperparameters: Iterations={best_hyperparameters[0]}, Alpha={best_hyperparameters[1]}, Lambda={best_hyperparameters[2]}")
print(f"Best Cost: {best_cost}")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_29388\2984279591.py:7: RuntimeWarning: overflow encountered in matmul
#   return Theta @ X
# C:\Users\USER\AppData\Local\Temp\ipykernel_29388\2984279591.py:10: RuntimeWarning: overflow encountered in square
#   return np.nansum((prediction - R) ** 2)
# C:\Users\USER\AppData\Local\Temp\ipykernel_29388\2984279591.py:36: RuntimeWarning: overflow encountered in multiply
#   Theta[i][k] -= alpha * (np.nansum(error[i, :]*X[k, :]) + lambda_*Theta[i][k])
# C:\Users\USER\AppData\Local\Temp\ipykernel_29388\2984279591.py:37: RuntimeWarning: overflow encountered in multiply
#   X[k][j] -= alpha * (np.nansum(error[:,j]*Theta[:,k]) + lambda_*X[k][j])
# C:\Users\USER\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\USER\AppData\Local\Temp\ipykernel_29388\2984279591.py:36: RuntimeWarning: invalid value encountered in double_scalars
#   Theta[i][k] -= alpha * (np.nansum(error[i, :]*X[k, :]) + lambda_*Theta[i][k])
# C:\Users\USER\AppData\Local\Temp\ipykernel_29388\2984279591.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   X[k][j] -= alpha * (np.nansum(error[:,j]*Theta[:,k]) + lambda_*X[k][j])
# Best Hyperparameters: Iterations=300, Alpha=0.001, Lambda=0.01
# Best Cost: 7.482498529001101

# %%
KDA_df = pd.read_csv('./KDA_df.csv', index_col=0)

for row in KDA_df.values:
    row -= np.nanmean(row)
    
R = KDA_df.values

Theta, X = initialize(R, 5)

Theta, X, costs = gradient_descent(R, Theta, X, 300, 0.001, 0.01)

# %%
Theta
# Out:
# array([[-9.32236812e-02, -4.77012854e-01,  8.44007256e-02,
#          3.12234607e-01,  1.86988723e-01],
#        [ 8.58445184e-01,  4.55524573e-01, -8.94242272e-01,
#         -3.38690719e-02,  4.10681085e-01],
#        [ 1.00020069e-02,  9.86056746e-01, -1.76223101e-01,
#         -3.72157372e-02,  1.14851666e-01],
#        [ 3.44235938e-01, -1.00977812e-01,  6.17145638e-01,
#         -1.80581930e-01,  6.77309957e-01],
